# %%
print("hello world")
# Out:
# hello world

# %%
a = {2,1,6,2,2,6,9,4,4}
print(a)
# Out:
# {1, 2, 4, 6, 9}

# %%
x = 4
y = 5
z = x < y
print(z)
# Out:
# True

# %%
x = "hello" 
y = "world"
z = x + y
print(z)
# Out:
# helloworld

# %%
first_name = "divyank"

# %%
name_1 = "divyank"
age = 18
married = True
print (name_1,age,married)
print (type(name_1,))
print (type(age))
print (type(married))
# Out:
# divyank 18 True
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
a = float(input("enter a number"))
print(type(a))
print(a)
# Out:
# <class 'float'>
# 54.0

# %%
a = 10
b = 20
c = 30
print(not(a<b or a>c))
# Out:
# False
